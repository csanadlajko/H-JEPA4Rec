# %%
# mount drive for dataset if needed
# from google.colab import drive
# drive.mount("/content/drive")

## /drive/MyDrive when using drive
# %cd /content
# !rm -r H-JEPA4REC
# !git clone https://github.com/csanadlajko/H-JEPA4REC.git
## /drive/MyDrive/H-JEPA4REC when using drive
# %cd /content/H-JEPA4REC
# Out:
# /content
# rm: cannot remove 'H-JEPA4REC': No such file or directory
# Cloning into 'H-JEPA4REC'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 117 (delta 35), reused 75 (delta 20), pack-reused 24 (from 1)
# Receiving objects: 100% (117/117), 43.74 MiB | 16.66 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/H-JEPA4REC

# %%
# !pip install -r requirements.txt
# !python train_hjepa.py --result_folder /content --epochs 1 --debug y --lr 0.00003
# Out:
# ...
# Starting temporary training on device: cuda
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 119kB/s]
# vocab.json: 1.04MB [00:00, 113MB/s]
# merges.txt: 456kB [00:00, 106MB/s]
# tokenizer.json: 1.36MB [00:00, 112MB/s]
# ...
# Architecture has: 25649408 trainable parameters.
# Training for 1 epochs...
# Starting epoch: 1
#   1% 5613/418026 [04:49<7:44:59, 14.78it/s]loss at iter 5000 is 0.1146
#   3% 11212/418026 [10:13<5:37:09, 20.11it/s]loss at iter 10000 is 0.0776
#   4% 16932/418026 [14:54<7:45:38, 14.36it/s]loss at iter 15000 is 0.1467
#   5% 22553/418026 [20:19<10:55:41, 10.05it/s]loss at iter 20000 is 0.2786
#   7% 28330/418026 [24:49<4:11:49, 25.79it/s]loss at iter 25000 is 0.0321
#   8% 33772/418026 [30:29<6:46:19, 15.76it/s]loss at iter 30000 is 0.3212
#   9% 39471/418026 [35:36<5:29:18, 19.16it/s]loss at iter 35000 is 0.4649
#  11% 45073/418026 [40:29<3:45:54, 27.51it/s]loss at iter 40000 is 0.0566
#  12% 50706/418026 [44:55<5:47:11, 17.63it/s]loss at iter 45000 is 0.2426
# ...
